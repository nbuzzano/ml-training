# %%
from IPython.display import Image, display;

# %% [markdown]
# # Informe

# %% [markdown]
# ### Bauxite distribution
#
# Being the distribution of bauxite_kg approximately normal, the expected value of bauxite to extract from an asteroid will be between:
#
# => (mean - std ; mean + std)
#
# * mean = expected value = 5.986221
#
# * std = standard desviation = 2.177836

# %% [markdown]
# ### Correlation between violet_stone_count and bauxite_kg
#
# Being the correlation = 0.9781637250632228
#
# We affirm that the linear relationship between violet_stone_count and bauxite_kg is very strong.
#
# It is noted that the presence of correlation does not imply causation.

# %% [markdown]
# ### Analysis and visual confirmation

# %%
Image(filename='output1.png', width=500)

# %% [markdown]
# - We visually confirm the linear relationship between variables
# - Visually no outliers are detected

# %% [markdown]
# ### Representative function:
# The function that represents the relationships between variables in the dataset is:
# - Y (X = violet_stone_count) = 0.05151773 * X + 1.89389521 -> bauxite_kg in asteroid
#
# In other words, if you can count violet_stone_count on an asteroid, using the provided function you can estimate how much bauxite_kg you expect to find on the asteroid.

# %% [markdown]
# ### Observations
# - precision measuring instrument: Error 0 is assumed in measuring instruments.
# - precision counting of violet stones: It is assumed that the asteroid count was correct in all cases.
